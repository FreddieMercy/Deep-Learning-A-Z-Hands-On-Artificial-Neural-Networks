# %%
import tensorflow as tf
import pandas as pd

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
# Lets define some constants to help us later on

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

X_train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
X_test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

Y_train = X_train.pop('Species')
Y_test = X_test.pop('Species')

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
feature_column = []

for feature_name in X_train.columns:
  feature_column.append(tf.feature_column.numeric_column(key = feature_name))

print(feature_column)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[40,10],
                                  n_classes=3)
clf3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[50,10],
                                  n_classes=3)
clf4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,20],
                                  n_classes=3)
clf5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,30],
                                  n_classes=3)
clf6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,40],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[40,20],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[50,30],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[60,40],
                                  n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpoq0j9wu2
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpoq0j9wu2', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
# ! number of class cannot be 1 (or less) !
# clf_c1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
#                                   hidden_units=[30,10],
# 
#                                   n_classes=1)

# ! number of classes must be at least how many classes in the "label"
# clf_c2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
#                                   hidden_units=[30,10],
#                                   n_classes=2)

clf_c3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_c4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=4)
clf_c5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=5)
clf_c6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=6)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpp228lo_4
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpp228lo_4', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
clf_s1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpkqbjox4r
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpkqbjox4r', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
clf1.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf2.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_s1.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 1000
)
clf_s2.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 2000
)
clf_s3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 3000
)
clf_s4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 4000
)
clf_s5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_s6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 6000
)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpkdgwxdyt/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.9076872, step = 0
# INFO:tensorflow:global_step/sec: 399.141
# INFO:tensorflow:loss = 0.8278096, step = 100 (0.255 sec)
# INFO:tensorflow:global_step/sec: 483.312
# INFO:tensorflow:loss = 0.754153, step = 200 (0.204 sec)
# INFO:tensorflow:global_step/sec: 469.617
# INFO:tensorflow:loss = 0.69356936, step = 300 (0.216 sec)
# INFO:tensorflow:global_step/sec: 505.653
# INFO:tensorflow:loss = 0.6513895, step = 400 (0.196 sec)
# INFO:tensorflow:global_step/sec: 485.249
# ...

# %%
expected = ['Setosa', 'Versicolor', 'Virginica']
testData = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}

# %%
def interpretPredict(clf):
  for pred_dict in list(clf.predict(input_fn = lambda:tf.data.Dataset.from_tensor_slices(dict(testData)).batch(256))):
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%)'.format(
        SPECIES[class_id], 100 * probability))

# %%
interpretPredict(clf1)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkdgwxdyt/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (92.9%)
# Prediction is "Versicolor" (70.8%)
# Prediction is "Virginica" (69.1%)

# %%
interpretPredict(clf2)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpy9pazz9u/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (90.6%)
# Prediction is "Versicolor" (61.3%)
# Prediction is "Virginica" (62.2%)

# %%
interpretPredict(clf3)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpa0fearwh/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (73.0%)
# Prediction is "Versicolor" (55.4%)
# Prediction is "Virginica" (64.1%)

# %%
interpretPredict(clf4)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpxf2jqhq2/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (80.0%)
# Prediction is "Versicolor" (49.1%)
# Prediction is "Virginica" (63.6%)

# %%
interpretPredict(clf5)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp1mxs636w/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (88.2%)
# Prediction is "Versicolor" (57.9%)
# Prediction is "Virginica" (67.6%)

# %%
interpretPredict(clf6)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpzjylxsko/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (91.3%)
# Prediction is "Versicolor" (71.3%)
# Prediction is "Virginica" (71.5%)

# %%
interpretPredict(clf_c3)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpp228lo_4/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (81.0%)
# Prediction is "Versicolor" (53.5%)
# Prediction is "Virginica" (63.5%)

# %%
interpretPredict(clf_c4)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpv17rmn5t/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (93.2%)
# Prediction is "Versicolor" (50.1%)
# Prediction is "Virginica" (61.1%)

# %%
interpretPredict(clf_c5)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp15nwzf2p/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (83.2%)
# Prediction is "Virginica" (47.2%)
# Prediction is "Virginica" (59.7%)

# %%
interpretPredict(clf_c6)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp2u_qmkg1/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (82.2%)
# Prediction is "Versicolor" (50.4%)
# Prediction is "Virginica" (65.2%)

# %%
interpretPredict(clf_s1)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpkqbjox4r/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (82.2%)
# Prediction is "Virginica" (52.7%)
# Prediction is "Virginica" (70.2%)

# %%
interpretPredict(clf_s2)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdu6zx_jr/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (34.3%)
# Prediction is "Virginica" (42.5%)
# Prediction is "Virginica" (54.9%)

# %%
interpretPredict(clf_s3)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp637u2rx8/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (75.9%)
# Prediction is "Versicolor" (39.6%)
# Prediction is "Versicolor" (44.1%)

# %%
interpretPredict(clf_s4)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpeli4y1bs/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (73.3%)
# Prediction is "Virginica" (44.1%)
# Prediction is "Virginica" (60.6%)

# %%
interpretPredict(clf_s5)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpsx9_w4g0/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (74.9%)
# Prediction is "Versicolor" (46.8%)
# Prediction is "Virginica" (63.7%)

# %%
interpretPredict(clf_s6)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp09_1d_4y/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "Setosa" (60.3%)
# Prediction is "Versicolor" (59.4%)
# Prediction is "Virginica" (68.8%)
