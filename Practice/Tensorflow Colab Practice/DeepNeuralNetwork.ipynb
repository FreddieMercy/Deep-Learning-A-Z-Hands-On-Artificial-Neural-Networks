# %%
import tensorflow as tf
import pandas as pd

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
# Lets define some constants to help us later on

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

X_train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
Y_test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

Y_train = X_train.pop('Species')
Y_test = Y_test.pop('Species')

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
feature_column = []

for feature_name in X_train.columns:
  feature_column.append(tf.feature_column.numeric_column(key = feature_name))

print(feature_column)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[40,10],
                                  n_classes=3)
clf3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[50,10],
                                  n_classes=3)
clf4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,20],
                                  n_classes=3)
clf5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,30],
                                  n_classes=3)
clf6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,40],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[40,20],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[50,30],
                                  n_classes=3)
clf1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[60,40],
                                  n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpatsoc7pv
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpatsoc7pv', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp_353ch3y
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp_353ch3y', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp5dr74vcj
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp5dr74vcj', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpegutgzv0
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpegutgzv0', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdg8cr_s0
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpdg8cr_s0', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp5i0tzez0
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp5i0tzez0', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp132q8gew
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp132q8gew', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpf4538oms
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpf4538oms', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp5ka6bdec
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp5ka6bdec', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# clf_c1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
#                                   hidden_units=[30,10],
#                                   n_classes=1)
clf_c2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=2)
clf_c3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_c4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=4)
clf_c5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=5)
clf_c6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=6)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9suaglbx
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp9suaglbx', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpsdi91kc5
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpsdi91kc5', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbew9xf7b
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpbew9xf7b', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpzn7rnja6
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpzn7rnja6', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp5enjk92e
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp5enjk92e', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
clf_s1 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s2 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s3 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s4 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s5 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
clf_s6 = tf.estimator.DNNClassifier(feature_columns=feature_column, 
                                  hidden_units=[30,10],
                                  n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpjrmlgazk
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpjrmlgazk', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmparnmdyav
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmparnmdyav', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp08gx9exb
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp08gx9exb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp1uz24s6f
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmp1uz24s6f', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdr1dh9wu
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpdr1dh9wu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpk760ov_a
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpk760ov_a', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
clf1.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf2.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)

clf_c2.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_c6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_s1.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 1000
)
clf_s2.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 2000
)
clf_s3.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 3000
)
clf_s4.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 4000
)
clf_s5.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 5000
)
clf_s6.train(
    input_fn = lambda:input_fn(X_train, Y_train, training=True),
    steps = 6000
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp5ka6bdec/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.3253924, step = 0
# INFO:tensorflow:global_step/sec: 403.229
# INFO:tensorflow:loss = 0.9821566, step = 100 (0.252 sec)
# INFO:tensorflow:global_step/sec: 437.061
# INFO:tensorflow:loss = 0.88926667, step = 200 (0.227 sec)
# INFO:tensorflow:global_step/sec: 452.047
# INFO:tensorflow:loss = 0.81710404, step = 300 (0.223 sec)
# INFO:tensorflow:global_step/sec: 460.196
# INFO:tensorflow:loss = 0.7705662, step = 400 (0.216 sec)
# INFO:tensorflow:global_step/sec: 455.017
# INFO:tensorflow:loss = 0.697667, step = 500 (0.220 sec)
# INFO:tensorflow:global_step/sec: 456.96
# INFO:tensorflow:loss = 0.6574333, step = 600 (0.218 sec)
# INFO:tensorflow:global_step/sec: 460.536
# INFO:tensorflow:loss = 0.6098155, step = 700 (0.221 sec)
# INFO:tensorflow:global_step/sec: 450.422
# INFO:tensorflow:loss = 0.57360274, step = 800 (0.218 sec)
# INFO:tensorflow:global_step/sec: 486.526
# INFO:tensorflow:loss = 0.5430598, step = 900 (0.205 sec)
# INFO:tensorflow:global_step/sec: 490.389
# INFO:tensorflow:loss = 0.50365996, step = 1000 (0.207 sec)
# INFO:tensorflow:global_step/sec: 444.353
# INFO:tensorflow:loss = 0.50946456, step = 1100 (0.227 sec)
# INFO:tensorflow:global_step/sec: 446.761
# INFO:tensorflow:loss = 0.47678643, step = 1200 (0.222 sec)
# INFO:tensorflow:global_step/sec: 454.755
# INFO:tensorflow:loss = 0.45190865, step = 1300 (0.221 sec)
# INFO:tensorflow:global_step/sec: 417.874
# INFO:tensorflow:loss = 0.44411534, step = 1400 (0.235 sec)
# INFO:tensorflow:global_step/sec: 406.29
# INFO:tensorflow:loss = 0.4210452, step = 1500 (0.249 sec)
# INFO:tensorflow:global_step/sec: 442.227
# INFO:tensorflow:loss = 0.41034284, step = 1600 (0.224 sec)
# INFO:tensorflow:global_step/sec: 442.185
# INFO:tensorflow:loss = 0.3853436, step = 1700 (0.229 sec)
# INFO:tensorflow:global_step/sec: 454.331
# INFO:tensorflow:loss = 0.38509697, step = 1800 (0.221 sec)
# INFO:tensorflow:global_step/sec: 399.307
# INFO:tensorflow:loss = 0.38354978, step = 1900 (0.250 sec)
# INFO:tensorflow:global_step/sec: 441.566
# INFO:tensorflow:loss = 0.36986405, step = 2000 (0.223 sec)
# INFO:tensorflow:global_step/sec: 415.288
# INFO:tensorflow:loss = 0.35105428, step = 2100 (0.243 sec)
# INFO:tensorflow:global_step/sec: 447.52
# INFO:tensorflow:loss = 0.33424622, step = 2200 (0.223 sec)
# INFO:tensorflow:global_step/sec: 440.769
# INFO:tensorflow:loss = 0.32752454, step = 2300 (0.226 sec)
# INFO:tensorflow:global_step/sec: 420.622
# INFO:tensorflow:loss = 0.32374018, step = 2400 (0.241 sec)
# INFO:tensorflow:global_step/sec: 448.464
# INFO:tensorflow:loss = 0.3127455, step = 2500 (0.220 sec)
# INFO:tensorflow:global_step/sec: 464.497
# INFO:tensorflow:loss = 0.30681163, step = 2600 (0.215 sec)
# INFO:tensorflow:global_step/sec: 490.971
# INFO:tensorflow:loss = 0.30141336, step = 2700 (0.204 sec)
# INFO:tensorflow:global_step/sec: 493.739
# INFO:tensorflow:loss = 0.29282695, step = 2800 (0.205 sec)
# INFO:tensorflow:global_step/sec: 408.052
# INFO:tensorflow:loss = 0.28408736, step = 2900 (0.242 sec)
# INFO:tensorflow:global_step/sec: 488.842
# INFO:tensorflow:loss = 0.2765173, step = 3000 (0.207 sec)
# INFO:tensorflow:global_step/sec: 502.498
# INFO:tensorflow:loss = 0.2773041, step = 3100 (0.199 sec)
# INFO:tensorflow:global_step/sec: 445.269
# INFO:tensorflow:loss = 0.26605177, step = 3200 (0.223 sec)
# INFO:tensorflow:global_step/sec: 454.071
# INFO:tensorflow:loss = 0.26325858, step = 3300 (0.223 sec)
# INFO:tensorflow:global_step/sec: 397.508
# INFO:tensorflow:loss = 0.25441414, step = 3400 (0.248 sec)
# INFO:tensorflow:global_step/sec: 452.795
# INFO:tensorflow:loss = 0.2483397, step = 3500 (0.223 sec)
# INFO:tensorflow:global_step/sec: 450.063
# INFO:tensorflow:loss = 0.2537111, step = 3600 (0.220 sec)
# INFO:tensorflow:global_step/sec: 416.601
# INFO:tensorflow:loss = 0.23613453, step = 3700 (0.240 sec)
# INFO:tensorflow:global_step/sec: 422.084
# INFO:tensorflow:loss = 0.25021458, step = 3800 (0.237 sec)
# INFO:tensorflow:global_step/sec: 453.409
# INFO:tensorflow:loss = 0.24077016, step = 3900 (0.223 sec)
# INFO:tensorflow:global_step/sec: 472.35
# INFO:tensorflow:loss = 0.22759327, step = 4000 (0.208 sec)
# INFO:tensorflow:global_step/sec: 481.639
# INFO:tensorflow:loss = 0.23248775, step = 4100 (0.208 sec)
# INFO:tensorflow:global_step/sec: 507.54
# INFO:tensorflow:loss = 0.22036171, step = 4200 (0.198 sec)
# INFO:tensorflow:global_step/sec: 458.386
# INFO:tensorflow:loss = 0.20863277, step = 4300 (0.220 sec)
# INFO:tensorflow:global_step/sec: 453.476
# INFO:tensorflow:loss = 0.20410854, step = 4400 (0.221 sec)
# INFO:tensorflow:global_step/sec: 467.735
# INFO:tensorflow:loss = 0.20481625, step = 4500 (0.213 sec)
# INFO:tensorflow:global_step/sec: 484.268
# INFO:tensorflow:loss = 0.2101968, step = 4600 (0.204 sec)
# INFO:tensorflow:global_step/sec: 447.882
# INFO:tensorflow:loss = 0.20029092, step = 4700 (0.225 sec)
# INFO:tensorflow:global_step/sec: 506.942
# INFO:tensorflow:loss = 0.19502322, step = 4800 (0.195 sec)
# INFO:tensorflow:global_step/sec: 473.977
# INFO:tensorflow:loss = 0.18184258, step = 4900 (0.211 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp5ka6bdec/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.19415973.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp_353ch3y/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 2.0840068, step = 0
# INFO:tensorflow:global_step/sec: 402.99
# INFO:tensorflow:loss = 1.3802589, step = 100 (0.253 sec)
# INFO:tensorflow:global_step/sec: 456.182
# INFO:tensorflow:loss = 1.2660496, step = 200 (0.216 sec)
# INFO:tensorflow:global_step/sec: 444.247
# INFO:tensorflow:loss = 1.1985867, step = 300 (0.227 sec)
# INFO:tensorflow:global_step/sec: 432.808
# INFO:tensorflow:loss = 1.137723, step = 400 (0.232 sec)
# INFO:tensorflow:global_step/sec: 487.355
# INFO:tensorflow:loss = 1.0909629, step = 500 (0.205 sec)
# INFO:tensorflow:global_step/sec: 432.556
# INFO:tensorflow:loss = 1.0689532, step = 600 (0.234 sec)
# INFO:tensorflow:global_step/sec: 427.757
# INFO:tensorflow:loss = 1.0232786, step = 700 (0.229 sec)
# INFO:tensorflow:global_step/sec: 488.845
# INFO:tensorflow:loss = 1.012313, step = 800 (0.208 sec)
# INFO:tensorflow:global_step/sec: 469.586
# INFO:tensorflow:loss = 1.0013934, step = 900 (0.213 sec)
# INFO:tensorflow:global_step/sec: 402.177
# INFO:tensorflow:loss = 0.9810133, step = 1000 (0.248 sec)
# INFO:tensorflow:global_step/sec: 381.997
# INFO:tensorflow:loss = 0.9737792, step = 1100 (0.261 sec)
# INFO:tensorflow:global_step/sec: 443.135
# INFO:tensorflow:loss = 0.9557607, step = 1200 (0.224 sec)
# INFO:tensorflow:global_step/sec: 477.929
# INFO:tensorflow:loss = 0.93442893, step = 1300 (0.213 sec)
# INFO:tensorflow:global_step/sec: 464.723
# INFO:tensorflow:loss = 0.92947793, step = 1400 (0.211 sec)
# INFO:tensorflow:global_step/sec: 469.279
# INFO:tensorflow:loss = 0.9175743, step = 1500 (0.216 sec)
# INFO:tensorflow:global_step/sec: 473.77
# INFO:tensorflow:loss = 0.9240498, step = 1600 (0.211 sec)
# INFO:tensorflow:global_step/sec: 430.12
# INFO:tensorflow:loss = 0.87718886, step = 1700 (0.231 sec)
# INFO:tensorflow:global_step/sec: 441.008
# INFO:tensorflow:loss = 0.875966, step = 1800 (0.230 sec)
# INFO:tensorflow:global_step/sec: 460.187
# INFO:tensorflow:loss = 0.8696053, step = 1900 (0.214 sec)
# INFO:tensorflow:global_step/sec: 403.969
# INFO:tensorflow:loss = 0.85774744, step = 2000 (0.248 sec)
# INFO:tensorflow:global_step/sec: 464.737
# INFO:tensorflow:loss = 0.8345288, step = 2100 (0.217 sec)
# INFO:tensorflow:global_step/sec: 500.08
# INFO:tensorflow:loss = 0.8221359, step = 2200 (0.196 sec)
# INFO:tensorflow:global_step/sec: 528.657
# INFO:tensorflow:loss = 0.81514627, step = 2300 (0.193 sec)
# INFO:tensorflow:global_step/sec: 445.087
# INFO:tensorflow:loss = 0.81285214, step = 2400 (0.224 sec)
# INFO:tensorflow:global_step/sec: 413.438
# INFO:tensorflow:loss = 0.7966509, step = 2500 (0.242 sec)
# INFO:tensorflow:global_step/sec: 493.131
# INFO:tensorflow:loss = 0.7819502, step = 2600 (0.205 sec)
# INFO:tensorflow:global_step/sec: 448.278
# INFO:tensorflow:loss = 0.771222, step = 2700 (0.221 sec)
# INFO:tensorflow:global_step/sec: 453.395
# INFO:tensorflow:loss = 0.7678602, step = 2800 (0.218 sec)
# INFO:tensorflow:global_step/sec: 430.374
# INFO:tensorflow:loss = 0.7604395, step = 2900 (0.235 sec)
# INFO:tensorflow:global_step/sec: 507.34
# INFO:tensorflow:loss = 0.7414701, step = 3000 (0.200 sec)
# INFO:tensorflow:global_step/sec: 478.672
# INFO:tensorflow:loss = 0.7360357, step = 3100 (0.202 sec)
# INFO:tensorflow:global_step/sec: 485.958
# INFO:tensorflow:loss = 0.7228619, step = 3200 (0.209 sec)
# INFO:tensorflow:global_step/sec: 490.327
# INFO:tensorflow:loss = 0.7097984, step = 3300 (0.200 sec)
# INFO:tensorflow:global_step/sec: 454.192
# INFO:tensorflow:loss = 0.6928619, step = 3400 (0.220 sec)
# INFO:tensorflow:global_step/sec: 442.337
# INFO:tensorflow:loss = 0.69448704, step = 3500 (0.227 sec)
# INFO:tensorflow:global_step/sec: 496.032
# INFO:tensorflow:loss = 0.67693555, step = 3600 (0.203 sec)
# INFO:tensorflow:global_step/sec: 522.685
# INFO:tensorflow:loss = 0.6749986, step = 3700 (0.189 sec)
# INFO:tensorflow:global_step/sec: 484.63
# INFO:tensorflow:loss = 0.6723778, step = 3800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 500.385
# INFO:tensorflow:loss = 0.65475786, step = 3900 (0.198 sec)
# INFO:tensorflow:global_step/sec: 505.199
# INFO:tensorflow:loss = 0.65552676, step = 4000 (0.198 sec)
# INFO:tensorflow:global_step/sec: 484.015
# INFO:tensorflow:loss = 0.6401463, step = 4100 (0.206 sec)
# INFO:tensorflow:global_step/sec: 487.4
# INFO:tensorflow:loss = 0.62998545, step = 4200 (0.208 sec)
# INFO:tensorflow:global_step/sec: 508.768
# INFO:tensorflow:loss = 0.6385768, step = 4300 (0.197 sec)
# INFO:tensorflow:global_step/sec: 488.173
# INFO:tensorflow:loss = 0.6225953, step = 4400 (0.202 sec)
# INFO:tensorflow:global_step/sec: 530.734
# INFO:tensorflow:loss = 0.6138714, step = 4500 (0.192 sec)
# INFO:tensorflow:global_step/sec: 449.463
# INFO:tensorflow:loss = 0.5891997, step = 4600 (0.219 sec)
# INFO:tensorflow:global_step/sec: 468.043
# INFO:tensorflow:loss = 0.59413356, step = 4700 (0.213 sec)
# INFO:tensorflow:global_step/sec: 443.203
# INFO:tensorflow:loss = 0.57036465, step = 4800 (0.231 sec)
# INFO:tensorflow:global_step/sec: 419.357
# INFO:tensorflow:loss = 0.55060196, step = 4900 (0.235 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp_353ch3y/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.5508587.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp5dr74vcj/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.3081932, step = 0
# INFO:tensorflow:global_step/sec: 383.916
# INFO:tensorflow:loss = 1.0755292, step = 100 (0.265 sec)
# INFO:tensorflow:global_step/sec: 489.018
# INFO:tensorflow:loss = 1.0147164, step = 200 (0.203 sec)
# INFO:tensorflow:global_step/sec: 456.056
# INFO:tensorflow:loss = 0.97272754, step = 300 (0.218 sec)
# INFO:tensorflow:global_step/sec: 437.487
# INFO:tensorflow:loss = 0.9501137, step = 400 (0.229 sec)
# INFO:tensorflow:global_step/sec: 506.638
# INFO:tensorflow:loss = 0.9269606, step = 500 (0.198 sec)
# INFO:tensorflow:global_step/sec: 499.522
# INFO:tensorflow:loss = 0.90532386, step = 600 (0.200 sec)
# INFO:tensorflow:global_step/sec: 452.261
# INFO:tensorflow:loss = 0.8894868, step = 700 (0.221 sec)
# INFO:tensorflow:global_step/sec: 448.679
# INFO:tensorflow:loss = 0.8751387, step = 800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 492.625
# INFO:tensorflow:loss = 0.8625337, step = 900 (0.201 sec)
# INFO:tensorflow:global_step/sec: 487.343
# INFO:tensorflow:loss = 0.84161824, step = 1000 (0.207 sec)
# INFO:tensorflow:global_step/sec: 503.228
# INFO:tensorflow:loss = 0.8267524, step = 1100 (0.198 sec)
# INFO:tensorflow:global_step/sec: 478.184
# INFO:tensorflow:loss = 0.81535834, step = 1200 (0.210 sec)
# INFO:tensorflow:global_step/sec: 442.124
# INFO:tensorflow:loss = 0.80335265, step = 1300 (0.225 sec)
# INFO:tensorflow:global_step/sec: 474.351
# INFO:tensorflow:loss = 0.78934985, step = 1400 (0.208 sec)
# INFO:tensorflow:global_step/sec: 478.46
# INFO:tensorflow:loss = 0.7761024, step = 1500 (0.214 sec)
# INFO:tensorflow:global_step/sec: 468.166
# INFO:tensorflow:loss = 0.7714276, step = 1600 (0.211 sec)
# INFO:tensorflow:global_step/sec: 464.707
# INFO:tensorflow:loss = 0.75315654, step = 1700 (0.214 sec)
# INFO:tensorflow:global_step/sec: 467.069
# INFO:tensorflow:loss = 0.7395419, step = 1800 (0.216 sec)
# INFO:tensorflow:global_step/sec: 521.977
# INFO:tensorflow:loss = 0.7255731, step = 1900 (0.191 sec)
# INFO:tensorflow:global_step/sec: 464.827
# INFO:tensorflow:loss = 0.6969445, step = 2000 (0.212 sec)
# INFO:tensorflow:global_step/sec: 479.949
# INFO:tensorflow:loss = 0.6800284, step = 2100 (0.211 sec)
# INFO:tensorflow:global_step/sec: 439.217
# INFO:tensorflow:loss = 0.68340707, step = 2200 (0.228 sec)
# INFO:tensorflow:global_step/sec: 453.312
# INFO:tensorflow:loss = 0.65638345, step = 2300 (0.217 sec)
# INFO:tensorflow:global_step/sec: 487.919
# INFO:tensorflow:loss = 0.6267501, step = 2400 (0.205 sec)
# INFO:tensorflow:global_step/sec: 466.872
# INFO:tensorflow:loss = 0.6180885, step = 2500 (0.214 sec)
# INFO:tensorflow:global_step/sec: 495.532
# INFO:tensorflow:loss = 0.60831034, step = 2600 (0.202 sec)
# INFO:tensorflow:global_step/sec: 494.901
# INFO:tensorflow:loss = 0.58560205, step = 2700 (0.204 sec)
# INFO:tensorflow:global_step/sec: 511.893
# INFO:tensorflow:loss = 0.5825267, step = 2800 (0.195 sec)
# INFO:tensorflow:global_step/sec: 506.547
# INFO:tensorflow:loss = 0.572289, step = 2900 (0.195 sec)
# INFO:tensorflow:global_step/sec: 511.711
# INFO:tensorflow:loss = 0.55015624, step = 3000 (0.199 sec)
# INFO:tensorflow:global_step/sec: 462.084
# INFO:tensorflow:loss = 0.54039586, step = 3100 (0.213 sec)
# INFO:tensorflow:global_step/sec: 464.909
# INFO:tensorflow:loss = 0.5232502, step = 3200 (0.215 sec)
# INFO:tensorflow:global_step/sec: 491.25
# INFO:tensorflow:loss = 0.5127102, step = 3300 (0.204 sec)
# INFO:tensorflow:global_step/sec: 484.194
# INFO:tensorflow:loss = 0.5082052, step = 3400 (0.206 sec)
# INFO:tensorflow:global_step/sec: 471.633
# INFO:tensorflow:loss = 0.5003309, step = 3500 (0.212 sec)
# INFO:tensorflow:global_step/sec: 516.131
# INFO:tensorflow:loss = 0.4842374, step = 3600 (0.194 sec)
# INFO:tensorflow:global_step/sec: 431.322
# INFO:tensorflow:loss = 0.49157333, step = 3700 (0.232 sec)
# INFO:tensorflow:global_step/sec: 448.256
# INFO:tensorflow:loss = 0.4733446, step = 3800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 469.59
# INFO:tensorflow:loss = 0.46445453, step = 3900 (0.211 sec)
# INFO:tensorflow:global_step/sec: 417.627
# INFO:tensorflow:loss = 0.4575216, step = 4000 (0.240 sec)
# INFO:tensorflow:global_step/sec: 458.457
# INFO:tensorflow:loss = 0.45116645, step = 4100 (0.220 sec)
# INFO:tensorflow:global_step/sec: 425.536
# INFO:tensorflow:loss = 0.44073194, step = 4200 (0.232 sec)
# INFO:tensorflow:global_step/sec: 486.35
# INFO:tensorflow:loss = 0.42183006, step = 4300 (0.209 sec)
# INFO:tensorflow:global_step/sec: 439.743
# INFO:tensorflow:loss = 0.4192859, step = 4400 (0.224 sec)
# INFO:tensorflow:global_step/sec: 521.296
# INFO:tensorflow:loss = 0.42248583, step = 4500 (0.192 sec)
# INFO:tensorflow:global_step/sec: 502.807
# INFO:tensorflow:loss = 0.41709113, step = 4600 (0.201 sec)
# INFO:tensorflow:global_step/sec: 472.873
# INFO:tensorflow:loss = 0.40987402, step = 4700 (0.212 sec)
# INFO:tensorflow:global_step/sec: 457.333
# INFO:tensorflow:loss = 0.40000755, step = 4800 (0.217 sec)
# INFO:tensorflow:global_step/sec: 451.901
# INFO:tensorflow:loss = 0.38690677, step = 4900 (0.225 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp5dr74vcj/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.392066.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpegutgzv0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.0471104, step = 0
# INFO:tensorflow:global_step/sec: 400.724
# INFO:tensorflow:loss = 0.8954475, step = 100 (0.251 sec)
# INFO:tensorflow:global_step/sec: 510.212
# INFO:tensorflow:loss = 0.85611117, step = 200 (0.199 sec)
# INFO:tensorflow:global_step/sec: 489.182
# INFO:tensorflow:loss = 0.8050377, step = 300 (0.202 sec)
# INFO:tensorflow:global_step/sec: 475.422
# INFO:tensorflow:loss = 0.7682822, step = 400 (0.209 sec)
# INFO:tensorflow:global_step/sec: 507.17
# INFO:tensorflow:loss = 0.7433553, step = 500 (0.201 sec)
# INFO:tensorflow:global_step/sec: 472.397
# INFO:tensorflow:loss = 0.71586764, step = 600 (0.208 sec)
# INFO:tensorflow:global_step/sec: 496.468
# INFO:tensorflow:loss = 0.68997574, step = 700 (0.205 sec)
# INFO:tensorflow:global_step/sec: 498.48
# INFO:tensorflow:loss = 0.66901505, step = 800 (0.198 sec)
# INFO:tensorflow:global_step/sec: 472.23
# INFO:tensorflow:loss = 0.6405233, step = 900 (0.213 sec)
# INFO:tensorflow:global_step/sec: 464.162
# INFO:tensorflow:loss = 0.63196015, step = 1000 (0.217 sec)
# INFO:tensorflow:global_step/sec: 478.613
# INFO:tensorflow:loss = 0.5991607, step = 1100 (0.206 sec)
# INFO:tensorflow:global_step/sec: 508.124
# INFO:tensorflow:loss = 0.5826489, step = 1200 (0.198 sec)
# INFO:tensorflow:global_step/sec: 455.954
# INFO:tensorflow:loss = 0.574502, step = 1300 (0.219 sec)
# INFO:tensorflow:global_step/sec: 461.549
# INFO:tensorflow:loss = 0.54592645, step = 1400 (0.220 sec)
# INFO:tensorflow:global_step/sec: 461.424
# INFO:tensorflow:loss = 0.53345776, step = 1500 (0.216 sec)
# INFO:tensorflow:global_step/sec: 495.709
# INFO:tensorflow:loss = 0.5281063, step = 1600 (0.202 sec)
# INFO:tensorflow:global_step/sec: 478.933
# INFO:tensorflow:loss = 0.5137148, step = 1700 (0.209 sec)
# INFO:tensorflow:global_step/sec: 486.503
# INFO:tensorflow:loss = 0.50555295, step = 1800 (0.202 sec)
# INFO:tensorflow:global_step/sec: 507.688
# INFO:tensorflow:loss = 0.491927, step = 1900 (0.200 sec)
# INFO:tensorflow:global_step/sec: 456.609
# INFO:tensorflow:loss = 0.48578823, step = 2000 (0.215 sec)
# INFO:tensorflow:global_step/sec: 480.689
# INFO:tensorflow:loss = 0.47575587, step = 2100 (0.211 sec)
# INFO:tensorflow:global_step/sec: 487.382
# INFO:tensorflow:loss = 0.45831746, step = 2200 (0.203 sec)
# INFO:tensorflow:global_step/sec: 514.144
# INFO:tensorflow:loss = 0.44458598, step = 2300 (0.194 sec)
# INFO:tensorflow:global_step/sec: 497.762
# INFO:tensorflow:loss = 0.44936737, step = 2400 (0.204 sec)
# INFO:tensorflow:global_step/sec: 502.912
# INFO:tensorflow:loss = 0.44749907, step = 2500 (0.197 sec)
# INFO:tensorflow:global_step/sec: 522.533
# INFO:tensorflow:loss = 0.41879296, step = 2600 (0.189 sec)
# INFO:tensorflow:global_step/sec: 522.983
# INFO:tensorflow:loss = 0.43224365, step = 2700 (0.191 sec)
# INFO:tensorflow:global_step/sec: 509.28
# INFO:tensorflow:loss = 0.41260374, step = 2800 (0.201 sec)
# INFO:tensorflow:global_step/sec: 481.307
# INFO:tensorflow:loss = 0.41598186, step = 2900 (0.210 sec)
# INFO:tensorflow:global_step/sec: 452.332
# INFO:tensorflow:loss = 0.41110975, step = 3000 (0.214 sec)
# INFO:tensorflow:global_step/sec: 495.432
# INFO:tensorflow:loss = 0.40772894, step = 3100 (0.202 sec)
# INFO:tensorflow:global_step/sec: 523.935
# INFO:tensorflow:loss = 0.37746018, step = 3200 (0.192 sec)
# INFO:tensorflow:global_step/sec: 459.9
# INFO:tensorflow:loss = 0.39704937, step = 3300 (0.217 sec)
# INFO:tensorflow:global_step/sec: 477.41
# INFO:tensorflow:loss = 0.39598832, step = 3400 (0.212 sec)
# INFO:tensorflow:global_step/sec: 457.326
# INFO:tensorflow:loss = 0.3733107, step = 3500 (0.215 sec)
# INFO:tensorflow:global_step/sec: 507.875
# INFO:tensorflow:loss = 0.3763996, step = 3600 (0.196 sec)
# INFO:tensorflow:global_step/sec: 497.344
# INFO:tensorflow:loss = 0.38188046, step = 3700 (0.205 sec)
# INFO:tensorflow:global_step/sec: 477.42
# INFO:tensorflow:loss = 0.36995786, step = 3800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 525.46
# INFO:tensorflow:loss = 0.36722687, step = 3900 (0.190 sec)
# INFO:tensorflow:global_step/sec: 494.78
# INFO:tensorflow:loss = 0.35871938, step = 4000 (0.201 sec)
# INFO:tensorflow:global_step/sec: 504.194
# INFO:tensorflow:loss = 0.3547909, step = 4100 (0.202 sec)
# INFO:tensorflow:global_step/sec: 466.684
# INFO:tensorflow:loss = 0.34861404, step = 4200 (0.209 sec)
# INFO:tensorflow:global_step/sec: 506.538
# INFO:tensorflow:loss = 0.33881915, step = 4300 (0.198 sec)
# INFO:tensorflow:global_step/sec: 507.548
# INFO:tensorflow:loss = 0.33935934, step = 4400 (0.200 sec)
# INFO:tensorflow:global_step/sec: 500.675
# INFO:tensorflow:loss = 0.33415562, step = 4500 (0.197 sec)
# INFO:tensorflow:global_step/sec: 508.709
# INFO:tensorflow:loss = 0.3315192, step = 4600 (0.196 sec)
# INFO:tensorflow:global_step/sec: 472.268
# INFO:tensorflow:loss = 0.32676744, step = 4700 (0.215 sec)
# INFO:tensorflow:global_step/sec: 527.906
# INFO:tensorflow:loss = 0.32397497, step = 4800 (0.186 sec)
# INFO:tensorflow:global_step/sec: 512.313
# INFO:tensorflow:loss = 0.33302248, step = 4900 (0.195 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpegutgzv0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.3020439.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpdg8cr_s0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.527054, step = 0
# INFO:tensorflow:global_step/sec: 398.668
# INFO:tensorflow:loss = 0.91708165, step = 100 (0.254 sec)
# INFO:tensorflow:global_step/sec: 482.342
# INFO:tensorflow:loss = 0.7934748, step = 200 (0.208 sec)
# INFO:tensorflow:global_step/sec: 472.31
# INFO:tensorflow:loss = 0.7159537, step = 300 (0.213 sec)
# INFO:tensorflow:global_step/sec: 480.64
# INFO:tensorflow:loss = 0.6697819, step = 400 (0.204 sec)
# INFO:tensorflow:global_step/sec: 479.345
# INFO:tensorflow:loss = 0.6353546, step = 500 (0.209 sec)
# INFO:tensorflow:global_step/sec: 485.983
# INFO:tensorflow:loss = 0.60856986, step = 600 (0.206 sec)
# INFO:tensorflow:global_step/sec: 450.927
# INFO:tensorflow:loss = 0.58983123, step = 700 (0.225 sec)
# INFO:tensorflow:global_step/sec: 474.978
# INFO:tensorflow:loss = 0.5695596, step = 800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 434.973
# INFO:tensorflow:loss = 0.55273175, step = 900 (0.229 sec)
# INFO:tensorflow:global_step/sec: 458.271
# INFO:tensorflow:loss = 0.54088736, step = 1000 (0.219 sec)
# INFO:tensorflow:global_step/sec: 455.114
# INFO:tensorflow:loss = 0.5257272, step = 1100 (0.222 sec)
# INFO:tensorflow:global_step/sec: 453.631
# INFO:tensorflow:loss = 0.50228596, step = 1200 (0.221 sec)
# INFO:tensorflow:global_step/sec: 462.3
# INFO:tensorflow:loss = 0.50346315, step = 1300 (0.213 sec)
# INFO:tensorflow:global_step/sec: 422.668
# INFO:tensorflow:loss = 0.47223973, step = 1400 (0.236 sec)
# INFO:tensorflow:global_step/sec: 492.079
# INFO:tensorflow:loss = 0.46995592, step = 1500 (0.204 sec)
# INFO:tensorflow:global_step/sec: 478.978
# INFO:tensorflow:loss = 0.46908253, step = 1600 (0.212 sec)
# INFO:tensorflow:global_step/sec: 508.243
# INFO:tensorflow:loss = 0.45525706, step = 1700 (0.194 sec)
# INFO:tensorflow:global_step/sec: 477.054
# INFO:tensorflow:loss = 0.44804165, step = 1800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 447.623
# INFO:tensorflow:loss = 0.45223165, step = 1900 (0.226 sec)
# INFO:tensorflow:global_step/sec: 457.385
# INFO:tensorflow:loss = 0.43886828, step = 2000 (0.219 sec)
# INFO:tensorflow:global_step/sec: 477.526
# INFO:tensorflow:loss = 0.4296251, step = 2100 (0.208 sec)
# INFO:tensorflow:global_step/sec: 465.68
# INFO:tensorflow:loss = 0.42431778, step = 2200 (0.215 sec)
# INFO:tensorflow:global_step/sec: 448.995
# INFO:tensorflow:loss = 0.41987368, step = 2300 (0.224 sec)
# INFO:tensorflow:global_step/sec: 452.405
# INFO:tensorflow:loss = 0.4067071, step = 2400 (0.219 sec)
# INFO:tensorflow:global_step/sec: 459.117
# INFO:tensorflow:loss = 0.38910085, step = 2500 (0.217 sec)
# INFO:tensorflow:global_step/sec: 432.818
# INFO:tensorflow:loss = 0.38779014, step = 2600 (0.229 sec)
# INFO:tensorflow:global_step/sec: 462.834
# INFO:tensorflow:loss = 0.39350247, step = 2700 (0.216 sec)
# INFO:tensorflow:global_step/sec: 451.253
# INFO:tensorflow:loss = 0.383245, step = 2800 (0.223 sec)
# INFO:tensorflow:global_step/sec: 452.066
# INFO:tensorflow:loss = 0.36585376, step = 2900 (0.223 sec)
# INFO:tensorflow:global_step/sec: 465.151
# INFO:tensorflow:loss = 0.3825339, step = 3000 (0.212 sec)
# INFO:tensorflow:global_step/sec: 483.543
# INFO:tensorflow:loss = 0.36949146, step = 3100 (0.206 sec)
# INFO:tensorflow:global_step/sec: 506.187
# INFO:tensorflow:loss = 0.36774313, step = 3200 (0.201 sec)
# INFO:tensorflow:global_step/sec: 448.383
# INFO:tensorflow:loss = 0.3631497, step = 3300 (0.223 sec)
# INFO:tensorflow:global_step/sec: 473.593
# INFO:tensorflow:loss = 0.3576733, step = 3400 (0.208 sec)
# INFO:tensorflow:global_step/sec: 458.679
# INFO:tensorflow:loss = 0.34444544, step = 3500 (0.219 sec)
# INFO:tensorflow:global_step/sec: 489.06
# INFO:tensorflow:loss = 0.35822538, step = 3600 (0.203 sec)
# INFO:tensorflow:global_step/sec: 460.176
# INFO:tensorflow:loss = 0.340838, step = 3700 (0.218 sec)
# INFO:tensorflow:global_step/sec: 456.915
# INFO:tensorflow:loss = 0.3363787, step = 3800 (0.220 sec)
# INFO:tensorflow:global_step/sec: 464.847
# INFO:tensorflow:loss = 0.33648044, step = 3900 (0.217 sec)
# INFO:tensorflow:global_step/sec: 429.856
# INFO:tensorflow:loss = 0.33649385, step = 4000 (0.230 sec)
# INFO:tensorflow:global_step/sec: 444.883
# INFO:tensorflow:loss = 0.33480233, step = 4100 (0.224 sec)
# INFO:tensorflow:global_step/sec: 421.015
# INFO:tensorflow:loss = 0.3300637, step = 4200 (0.241 sec)
# INFO:tensorflow:global_step/sec: 460.744
# INFO:tensorflow:loss = 0.33095467, step = 4300 (0.217 sec)
# INFO:tensorflow:global_step/sec: 470.197
# INFO:tensorflow:loss = 0.3271048, step = 4400 (0.209 sec)
# INFO:tensorflow:global_step/sec: 490.599
# INFO:tensorflow:loss = 0.3199507, step = 4500 (0.205 sec)
# INFO:tensorflow:global_step/sec: 454.766
# INFO:tensorflow:loss = 0.3067695, step = 4600 (0.221 sec)
# INFO:tensorflow:global_step/sec: 481.463
# INFO:tensorflow:loss = 0.31801262, step = 4700 (0.209 sec)
# INFO:tensorflow:global_step/sec: 473.133
# INFO:tensorflow:loss = 0.3089375, step = 4800 (0.210 sec)
# INFO:tensorflow:global_step/sec: 489.759
# INFO:tensorflow:loss = 0.3127222, step = 4900 (0.205 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmpdg8cr_s0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.3059721.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmp5i0tzez0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.1783717, step = 0
# INFO:tensorflow:global_step/sec: 342.13
# INFO:tensorflow:loss = 1.0209615, step = 100 (0.295 sec)
# INFO:tensorflow:global_step/sec: 420.592
# INFO:tensorflow:loss = 0.92520785, step = 200 (0.239 sec)
# INFO:tensorflow:global_step/sec: 480.558
# INFO:tensorflow:loss = 0.86723393, step = 300 (0.205 sec)
# INFO:tensorflow:global_step/sec: 505.77
# INFO:tensorflow:loss = 0.8298766, step = 400 (0.201 sec)
# INFO:tensorflow:global_step/sec: 476.801
# INFO:tensorflow:loss = 0.7736, step = 500 (0.212 sec)
# INFO:tensorflow:global_step/sec: 470.086
# INFO:tensorflow:loss = 0.7434641, step = 600 (0.209 sec)
# INFO:tensorflow:global_step/sec: 466.913
# INFO:tensorflow:loss = 0.7216513, step = 700 (0.213 sec)
# INFO:tensorflow:global_step/sec: 472.61
# INFO:tensorflow:loss = 0.67965084, step = 800 (0.214 sec)
# INFO:tensorflow:global_step/sec: 486.897
# INFO:tensorflow:loss = 0.6532343, step = 900 (0.202 sec)
# INFO:tensorflow:global_step/sec: 457.195
# INFO:tensorflow:loss = 0.63291466, step = 1000 (0.222 sec)
# INFO:tensorflow:global_step/sec: 457.549
# INFO:tensorflow:loss = 0.6095561, step = 1100 (0.219 sec)
# INFO:tensorflow:global_step/sec: 453.168
# INFO:tensorflow:loss = 0.5809937, step = 1200 (0.220 sec)
# INFO:tensorflow:global_step/sec: 471.686
# INFO:tensorflow:loss = 0.5712725, step = 1300 (0.211 sec)
# INFO:tensorflow:global_step/sec: 467.086
# INFO:tensorflow:loss = 0.55149573, step = 1400 (0.215 sec)
# INFO:tensorflow:global_step/sec: 492.533
# INFO:tensorflow:loss = 0.54186296, step = 1500 (0.200 sec)
# INFO:tensorflow:global_step/sec: 436.825
# INFO:tensorflow:loss = 0.51977396, step = 1600 (0.233 sec)
# INFO:tensorflow:global_step/sec: 426.145
# INFO:tensorflow:loss = 0.5195117, step = 1700 (0.235 sec)
# INFO:tensorflow:global_step/sec: 421.615
# INFO:tensorflow:loss = 0.5051261, step = 1800 (0.238 sec)
# INFO:tensorflow:global_step/sec: 400.057
# INFO:tensorflow:loss = 0.49013, step = 1900 (0.246 sec)
# INFO:tensorflow:global_step/sec: 400.339
# INFO:tensorflow:loss = 0.49711496, step = 2000 (0.250 sec)
# INFO:tensorflow:global_step/sec: 449.413
# INFO:tensorflow:loss = 0.47863644, step = 2100 (0.222 sec)
# INFO:tensorflow:global_step/sec: 437.774
# INFO:tensorflow:loss = 0.44424775, step = 2200 (0.233 sec)
# INFO:tensorflow:global_step/sec: 414.647
# INFO:tensorflow:loss = 0.46435016, step = 2300 (0.237 sec)
# INFO:tensorflow:global_step/sec: 455.981
# INFO:tensorflow:loss = 0.45003858, step = 2400 (0.224 sec)
# INFO:tensorflow:global_step/sec: 430.182
# INFO:tensorflow:loss = 0.437955, step = 2500 (0.228 sec)
# INFO:tensorflow:global_step/sec: 452.571
# INFO:tensorflow:loss = 0.43613386, step = 2600 (0.221 sec)
# INFO:tensorflow:global_step/sec: 455.362
# INFO:tensorflow:loss = 0.42530876, step = 2700 (0.223 sec)
# INFO:tensorflow:global_step/sec: 439.943
# INFO:tensorflow:loss = 0.417934, step = 2800 (0.226 sec)
# INFO:tensorflow:global_step/sec: 469.964
# INFO:tensorflow:loss = 0.40563256, step = 2900 (0.212 sec)
# INFO:tensorflow:global_step/sec: 436.684
# INFO:tensorflow:loss = 0.40090752, step = 3000 (0.228 sec)
# INFO:tensorflow:global_step/sec: 449.167
# INFO:tensorflow:loss = 0.39344603, step = 3100 (0.227 sec)
# INFO:tensorflow:global_step/sec: 425.751
# INFO:tensorflow:loss = 0.38524234, step = 3200 (0.231 sec)
# INFO:tensorflow:global_step/sec: 431.825
# INFO:tensorflow:loss = 0.39610657, step = 3300 (0.235 sec)
# INFO:tensorflow:global_step/sec: 464.548
# INFO:tensorflow:loss = 0.38984704, step = 3400 (0.211 sec)
# INFO:tensorflow:global_step/sec: 490.526
# INFO:tensorflow:loss = 0.38265342, step = 3500 (0.206 sec)
# INFO:tensorflow:global_step/sec: 426.962
# INFO:tensorflow:loss = 0.3683727, step = 3600 (0.237 sec)
# INFO:tensorflow:global_step/sec: 414.374
# INFO:tensorflow:loss = 0.37802845, step = 3700 (0.242 sec)
# INFO:tensorflow:global_step/sec: 426.453
# INFO:tensorflow:loss = 0.37026858, step = 3800 (0.230 sec)
# INFO:tensorflow:global_step/sec: 463.875
# INFO:tensorflow:loss = 0.36717516, step = 3900 (0.218 sec)
# INFO:tensorflow:global_step/sec: 448.705
# INFO:tensorflow:loss = 0.35520348, step = 4000 (0.220 sec)
# INFO:tensorflow:global_step/sec: 440.279
# INFO:tensorflow:loss = 0.3479421, step = 4100 (0.227 sec)
# INFO:tensorflow:global_step/sec: 424.371
# INFO:tensorflow:loss = 0.34358805, step = 4200 (0.235 sec)
# INFO:tensorflow:global_step/sec: 441.221
# INFO:tensorflow:loss = 0.34122807, step = 4300 (0.229 sec)
# INFO:tensorflow:global_step/sec: 442.865
# INFO:tensorflow:loss = 0.338661, step = 4400 (0.228 sec)
# INFO:tensorflow:global_step/sec: 463.313
# INFO:tensorflow:loss = 0.324678, step = 4500 (0.212 sec)
# INFO:tensorflow:global_step/sec: 455.533
# INFO:tensorflow:loss = 0.31765687, step = 4600 (0.221 sec)
# INFO:tensorflow:global_step/sec: 492.546
# INFO:tensorflow:loss = 0.31832433, step = 4700 (0.202 sec)
# INFO:tensorflow:global_step/sec: 481.935
# INFO:tensorflow:loss = 0.31735545, step = 4800 (0.207 sec)
# INFO:tensorflow:global_step/sec: 495.989
# INFO:tensorflow:loss = 0.3209983, step = 4900 (0.203 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /tmp/tmp5i0tzez0/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.31658286.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-9725cb51d95f> in <module>()
#      23     steps = 5000
#      24 )
# ---> 25 clf_c1.train(
#      26     input_fn = lambda:input_fn(X_train, Y_train, training=True),
#      27     steps = 5000
#
# NameError: name 'clf_c1' is not defined
