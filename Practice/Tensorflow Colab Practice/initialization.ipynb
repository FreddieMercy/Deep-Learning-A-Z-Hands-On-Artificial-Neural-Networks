# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf

# %%
print(tf.version.VERSION)
# Out:
# 2.4.1

# %%
var1 = tf.Variable("Variable (0d vector) is also a tensor, tensor is also can be variable (0d vector)", tf.string)
print(var1)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=string, numpy=b'Variable (0d vector) is also a tensor, tensor is also can be variable (0d vector)'>

# %%
rank1_tensor = tf.Variable(["rank","is same to","degree"], tf.string)
rank2_tensor = tf.Variable([["rank2", "means", "2d vector/rank 2 tensor"],["rank#", "means", "#d vector/rank # tensor"]], tf.string)

# %%
tf.rank(rank2_tensor)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=2>
