# %%
from sklearn import tree

dt_clf = tree.DecisionTreeClassifier()
data = [[0, 0], [1, 1], [2, 2], [3, 3]]
target = [0, 1, 2, 3]

dt_clf.fit(data, target)

print(dt_clf.predict([[100., -10.]]))
print(dt_clf.predict_proba([[100., -10.]]))  # probability of being one of the $(target.length) classes
tree.plot_tree(dt_clf)
# Out:
# [0]
# [[1. 0. 0. 0.]]
# [Text(111.60000000000001, 190.26, 'X[1] <= 0.5\ngini = 0.75\nsamples = 4\nvalue = [1, 1, 1, 1]'),
#  Text(55.800000000000004, 135.9, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(167.4, 135.9, 'X[0] <= 1.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1]'),
#  Text(111.60000000000001, 81.53999999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(223.20000000000002, 81.53999999999999, 'X[1] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(167.4, 27.180000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(279.0, 27.180000000000007, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]')]

# %%
print(tree.export_text(dt_clf))

import graphviz

graph = graphviz.Source(tree.export_graphviz(dt_clf))  # 'Source' means 'import/load'?
graph.render("tree_graph")
# Out:
# |--- feature_1 <= 0.50
# |   |--- class: 0
# |--- feature_1 >  0.50
# |   |--- feature_0 <= 1.50
# |   |   |--- class: 1
# |   |--- feature_0 >  1.50
# |   |   |--- feature_1 <= 2.50
# |   |   |   |--- class: 2
# |   |   |--- feature_1 >  2.50
# |   |   |   |--- class: 3
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-39209c8869e4> in <module>
#       1 print(tree.export_text(dt_clf))
#       2
# ----> 3 import graphviz
#       4
#       5 graph = graphviz.Source(tree.export_graphviz(dt_clf))  # 'Source' means 'import/load'?
#
# ModuleNotFoundError: No module named 'graphviz'
